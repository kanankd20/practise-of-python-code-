# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("student_data.csv")
df
# Out:
#     Student_ID  Gender    City  Study_Hours  Attendance  Marks Passed
# 0          101    Male    Pune          5.0        90.0   85.0    Yes
# 1          102  Female  Mumbai          4.0        85.0   78.0    Yes
# 2          103    Male  Nashik          6.0        95.0   92.0    Yes
# 3          104  Female    Pune          NaN        88.0   75.0    Yes
# 4          105    Male  Mumbai          3.0        70.0   60.0     No
# 5          106  Female  Nashik          7.0        98.0   96.0    Yes
# 6          107    Male    Pune          2.0        65.0   55.0     No
# 7          108  Female  Mumbai          5.0         NaN   80.0    Yes
# 8          109    Male  Nashik          4.0        82.0   72.0    Yes
# 9          110  Female    Pune          3.0        75.0   68.0     No
# 10         111    Male  Mumbai          8.0        99.0   98.0    Yes
# 11         112  Female  Nashik          6.0        92.0   89.0    Yes
# ...

# %%
df.head()
# Out:
#    Student_ID  Gender    City  Study_Hours  Attendance  Marks Passed
# 0         101    Male    Pune          5.0        90.0   85.0    Yes
# 1         102  Female  Mumbai          4.0        85.0   78.0    Yes
# 2         103    Male  Nashik          6.0        95.0   92.0    Yes
# 3         104  Female    Pune          NaN        88.0   75.0    Yes
# 4         105    Male  Mumbai          3.0        70.0   60.0     No

# %%
df.shape
# Out:
# (15, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Student_ID   15 non-null     int64
#  1   Gender       15 non-null     object
#  2   City         15 non-null     object
#  3   Study_Hours  13 non-null     float64
#  4   Attendance   14 non-null     float64
#  5   Marks        14 non-null     float64
#  6   Passed       15 non-null     object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 972.0+ bytes

# %%
df.isnull().sum()
# Out:
# Student_ID     0
# Gender         0
# City           0
# Study_Hours    2
# Attendance     1
# Marks          1
# Passed         0
# dtype: int64

# %%
df["Study_Hours"]=df["Study_Hours"].fillna(df["Study_Hours"].median())
df["Attendance"]=df["Attendance"].fillna(df["Attendance"].median())
df["Marks"]=df["Marks"].fillna(df["Marks"].median())
df
# Out:
#     Student_ID  Gender    City  Study_Hours  Attendance  Marks Passed
# 0          101    Male    Pune          5.0        90.0   85.0    Yes
# 1          102  Female  Mumbai          4.0        85.0   78.0    Yes
# 2          103    Male  Nashik          6.0        95.0   92.0    Yes
# 3          104  Female    Pune          5.0        88.0   75.0    Yes
# 4          105    Male  Mumbai          3.0        70.0   60.0     No
# 5          106  Female  Nashik          7.0        98.0   96.0    Yes
# 6          107    Male    Pune          2.0        65.0   55.0     No
# 7          108  Female  Mumbai          5.0        86.0   80.0    Yes
# 8          109    Male  Nashik          4.0        82.0   72.0    Yes
# 9          110  Female    Pune          3.0        75.0   68.0     No
# 10         111    Male  Mumbai          8.0        99.0   98.0    Yes
# 11         112  Female  Nashik          6.0        92.0   89.0    Yes
# ...

# %%
df.drop("City", axis=1,inplace=True)
df
# Out:
#     Student_ID  Gender  Study_Hours  Attendance  Marks Passed
# 0          101    Male          5.0        90.0   85.0    Yes
# 1          102  Female          4.0        85.0   78.0    Yes
# 2          103    Male          6.0        95.0   92.0    Yes
# 3          104  Female          5.0        88.0   75.0    Yes
# 4          105    Male          3.0        70.0   60.0     No
# 5          106  Female          7.0        98.0   96.0    Yes
# 6          107    Male          2.0        65.0   55.0     No
# 7          108  Female          5.0        86.0   80.0    Yes
# 8          109    Male          4.0        82.0   72.0    Yes
# 9          110  Female          3.0        75.0   68.0     No
# 10         111    Male          8.0        99.0   98.0    Yes
# 11         112  Female          6.0        92.0   89.0    Yes
# 12         113    Male          5.0        80.0   70.0    Yes
# 13         114  Female          2.0        60.0   50.0     No
# ...

# %%
df.drop("Student_ID",axis=1, inplace=True)
df["Gender"]=df["Gender"].map({
    "Male":0,
    "Female":1
})
df
# Out:
#     Gender  Study_Hours  Attendance  Marks Passed
# 0        0          5.0        90.0   85.0    Yes
# 1        1          4.0        85.0   78.0    Yes
# 2        0          6.0        95.0   92.0    Yes
# 3        1          5.0        88.0   75.0    Yes
# 4        0          3.0        70.0   60.0     No
# 5        1          7.0        98.0   96.0    Yes
# 6        0          2.0        65.0   55.0     No
# 7        1          5.0        86.0   80.0    Yes
# 8        0          4.0        82.0   72.0    Yes
# 9        1          3.0        75.0   68.0     No
# 10       0          8.0        99.0   98.0    Yes
# 11       1          6.0        92.0   89.0    Yes
# 12       0          5.0        80.0   70.0    Yes
# 13       1          2.0        60.0   50.0     No
# 14       0          5.0        87.0   76.5    Yes

# %%
df["Passed"]=df["Passed"].map({
    "Yes":1,
    "No":0
})
df
# Out:
#     Gender  Study_Hours  Attendance  Marks  Passed
# 0        0          5.0        90.0   85.0       1
# 1        1          4.0        85.0   78.0       1
# 2        0          6.0        95.0   92.0       1
# 3        1          5.0        88.0   75.0       1
# 4        0          3.0        70.0   60.0       0
# 5        1          7.0        98.0   96.0       1
# 6        0          2.0        65.0   55.0       0
# 7        1          5.0        86.0   80.0       1
# 8        0          4.0        82.0   72.0       1
# 9        1          3.0        75.0   68.0       0
# 10       0          8.0        99.0   98.0       1
# 11       1          6.0        92.0   89.0       1
# 12       0          5.0        80.0   70.0       1
# 13       1          2.0        60.0   50.0       0
# 14       0          5.0        87.0   76.5       1

# %%
x=df.drop("Passed",axis=1)
y=df["Passed"]
x
# Out:
#     Gender  Study_Hours  Attendance  Marks
# 0        0          5.0        90.0   85.0
# 1        1          4.0        85.0   78.0
# 2        0          6.0        95.0   92.0
# 3        1          5.0        88.0   75.0
# 4        0          3.0        70.0   60.0
# 5        1          7.0        98.0   96.0
# 6        0          2.0        65.0   55.0
# 7        1          5.0        86.0   80.0
# 8        0          4.0        82.0   72.0
# 9        1          3.0        75.0   68.0
# 10       0          8.0        99.0   98.0
# 11       1          6.0        92.0   89.0
# 12       0          5.0        80.0   70.0
# 13       1          2.0        60.0   50.0
# 14       0          5.0        87.0   76.5

# %%
y
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     0
# 5     1
# 6     0
# 7     1
# 8     1
# 9     0
# 10    1
# 11    1
# 12    1
# 13    0
# 14    1
# Name: Passed, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test= train_test_split(x, y, test_size=0.2, random_state=42)
x_train
# Out:
#     Gender  Study_Hours  Attendance  Marks
# 13       1          2.0        60.0   50.0
# 5        1          7.0        98.0   96.0
# 8        0          4.0        82.0   72.0
# 2        0          6.0        95.0   92.0
# 1        1          4.0        85.0   78.0
# 14       0          5.0        87.0   76.5
# 4        0          3.0        70.0   60.0
# 7        1          5.0        86.0   80.0
# 10       0          8.0        99.0   98.0
# 12       0          5.0        80.0   70.0
# 3        1          5.0        88.0   75.0
# 6        0          2.0        65.0   55.0

# %%
x_test
# Out:
#     Gender  Study_Hours  Attendance  Marks
# 9        1          3.0        75.0   68.0
# 11       1          6.0        92.0   89.0
# 0        0          5.0        90.0   85.0

# %%
y_train
# Out:
# 13    0
# 5     1
# 8     1
# 2     1
# 1     1
# 14    1
# 4     0
# 7     1
# 10    1
# 12    1
# 3     1
# 6     0
# Name: Passed, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)
x_train
# Out:
# array([[ 1.18321596, -1.52554014, -1.91923273, -1.71961763],
#        [ 1.18321596,  1.33484762,  1.26320409,  1.41832925],
#        [-0.84515425, -0.38138504, -0.07676931, -0.21886043],
#        [-0.84515425,  0.76277007,  1.01195908,  1.14546431],
#        [ 1.18321596, -0.38138504,  0.1744757 ,  0.19043699],
#        [-0.84515425,  0.19069252,  0.34197238,  0.08811264],
#        [-0.84515425, -0.95346259, -1.08174936, -1.03745527],
#        [ 1.18321596,  0.19069252,  0.25822404,  0.32686947],
#        [-0.84515425,  1.90692518,  1.34695243,  1.55476173],
#        [-0.84515425,  0.19069252, -0.24426598, -0.3552929 ],
#        [ 1.18321596,  0.19069252,  0.42572072, -0.01421172],
#        [-0.84515425, -1.52554014, -1.50049105, -1.37853645]])

# %%
x_test
# Out:
# array([[ 1.18321596, -0.95346259, -0.66300767, -0.49172537],
#        [ 1.18321596,  0.76277007,  0.76071407,  0.9408156 ],
#        [-0.84515425,  0.19069252,  0.59321739,  0.66795065]])

# %%
from sklearn.linear_model import LogisticRegression
model= LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred =model.predict(x_test)
y_pred
# Out:
# array([1, 1, 1])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.6666666666666666

# %%
#2nd question of loan approval predisvction 
df=pd.read_csv("Loan.csv")
df.head()
# Out:
#   ApplicationDate  Age  AnnualIncome  CreditScore EmploymentStatus  \
# 0      2018-01-01   45         39948          617         Employed
# 1      2018-01-02   38         39709          628         Employed
# 2      2018-01-03   47         40724          570         Employed
# 3      2018-01-04   58         69084          545         Employed
# 4      2018-01-05   37        103264          594         Employed
#
#   EducationLevel  Experience  LoanAmount  LoanDuration MaritalStatus  ...  \
# 0         Master          22       13152            48       Married  ...
# 1      Associate          15       26045            48        Single  ...
# 2       Bachelor          26       17627            36       Married  ...
# 3    High School          34       37898            96        Single  ...
# 4      Associate          17        9184            36       Married  ...
#
#    MonthlyIncome UtilityBillsPaymentHistory  JobTenure  NetWorth  \
# ...

# %%
df.shape
# Out:
# (20000, 36)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ApplicationDate             20000 non-null  object
#  1   Age                         20000 non-null  int64
#  2   AnnualIncome                20000 non-null  int64
#  3   CreditScore                 20000 non-null  int64
#  4   EmploymentStatus            20000 non-null  object
#  5   EducationLevel              20000 non-null  object
#  6   Experience                  20000 non-null  int64
#  7   LoanAmount                  20000 non-null  int64
#  8   LoanDuration                20000 non-null  int64
#  9   MaritalStatus               20000 non-null  object
#  10  NumberOfDependents          20000 non-null  int64
#  11  HomeOwnershipStatus         20000 non-null  object
#  12  MonthlyDebtPayments         20000 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# ApplicationDate               0
# Age                           0
# AnnualIncome                  0
# CreditScore                   0
# EmploymentStatus              0
# EducationLevel                0
# Experience                    0
# LoanAmount                    0
# LoanDuration                  0
# MaritalStatus                 0
# NumberOfDependents            0
# HomeOwnershipStatus           0
# MonthlyDebtPayments           0
# CreditCardUtilizationRate     0
# NumberOfOpenCreditLines       0
# NumberOfCreditInquiries       0
# DebtToIncomeRatio             0
# BankruptcyHistory             0
# LoanPurpose                   0
# PreviousLoanDefaults          0
# PaymentHistory                0
# LengthOfCreditHistory         0
# SavingsAccountBalance         0
# CheckingAccountBalance        0
# TotalAssets                   0
# TotalLiabilities              0
# MonthlyIncome                 0
# UtilityBillsPaymentHistory    0
# JobTenure                     0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop(columns=["ApplicationDate","Age"],axis=1,inplace=True)
df
# Out:
#        AnnualIncome  CreditScore EmploymentStatus EducationLevel  Experience  \
# 0             39948          617         Employed         Master          22
# 1             39709          628         Employed      Associate          15
# 2             40724          570         Employed       Bachelor          26
# 3             69084          545         Employed    High School          34
# 4            103264          594         Employed      Associate          17
# ...             ...          ...              ...            ...         ...
# 19995         30180          587         Employed    High School          19
# 19996         49246          567         Employed      Associate          33
# 19997         48958          645         Employed       Bachelor          20
# 19998         41025          560         Employed    High School          36
# 19999         53227          574         Employed      Associate           0
#
# ...

# %%
df.drop(
    columns=["Experience","LoanAmount","LoanDuration","MaritalStatus"],
    axis=1,
    inplace=True
)
df
# Out:
#        AnnualIncome  CreditScore EmploymentStatus EducationLevel  \
# 0             39948          617         Employed         Master
# 1             39709          628         Employed      Associate
# 2             40724          570         Employed       Bachelor
# 3             69084          545         Employed    High School
# 4            103264          594         Employed      Associate
# ...             ...          ...              ...            ...
# 19995         30180          587         Employed    High School
# 19996         49246          567         Employed      Associate
# 19997         48958          645         Employed       Bachelor
# 19998         41025          560         Employed    High School
# 19999         53227          574         Employed      Associate
#
#        NumberOfDependents HomeOwnershipStatus  MonthlyDebtPayments  \
# 0                       2                 Own                  183
# ...

# %%
df.drop(
    columns=["EducationLevel","EmploymentStatus","NumberOfDependents","MonthlyDebtPayments","CreditCardUtilizationRate","NumberOfCreditInquiries"],
    axis=1,
    inplace=True
)
df
# Out:
#        AnnualIncome  CreditScore HomeOwnershipStatus  NumberOfOpenCreditLines  \
# 0             39948          617                 Own                        1
# 1             39709          628            Mortgage                        5
# 2             40724          570                Rent                        2
# 3             69084          545            Mortgage                        2
# 4            103264          594            Mortgage                        0
# ...             ...          ...                 ...                      ...
# 19995         30180          587                Rent                        5
# 19996         49246          567                Rent                        2
# 19997         48958          645            Mortgage                        3
# 19998         41025          560                 Own                        4
# 19999         53227          574                 Own                        3
#
# ...

# %%
df.drop(
    columns=["HomeOwnershipStatus","NumberOfOpenCreditLines","DebtToIncomeRatio","BankruptcyHistory","LoanPurpose","PreviousLoanDefaults","PaymentHistory"],
    axis=1,
    inplace=True
)
df
# Out:
#        AnnualIncome  CreditScore  LengthOfCreditHistory  \
# 0             39948          617                      9
# 1             39709          628                      9
# 2             40724          570                     22
# 3             69084          545                     10
# 4            103264          594                     27
# ...             ...          ...                    ...
# 19995         30180          587                      7
# 19996         49246          567                     28
# 19997         48958          645                      8
# 19998         41025          560                     13
# 19999         53227          574                     14
#
#        SavingsAccountBalance  CheckingAccountBalance  TotalAssets  \
# 0                       7632                    1202       146111
# 1                       4627                    3460        53204
# 2                        886                     895        25176
# ...

# %%
df.drop(
    columns=["LengthOfCreditHistory","SavingsAccountBalance","CheckingAccountBalance","TotalAssets","TotalLiabilities","UtilityBillsPaymentHistory"],
    axis=1,
    inplace=True
)
df
# Out:
#        AnnualIncome  CreditScore  MonthlyIncome  JobTenure  NetWorth  \
# 0             39948          617    3329.000000         11    126928
# 1             39709          628    3309.083333          3     43609
# 2             40724          570    3393.666667          6      5205
# 3             69084          545    5757.000000          5     99452
# 4            103264          594    8605.333333          5    227019
# ...             ...          ...            ...        ...       ...
# 19995         30180          587    2515.000000          1     55327
# 19996         49246          567    4103.833333          3     64002
# 19997         48958          645    4079.833333          3    103663
# 19998         41025          560    3418.750000          5     10600
# 19999         53227          574    4435.583333          5     41372
#
#        BaseInterestRate  InterestRate  MonthlyLoanPayment  \
# 0              0.199652      0.227590          419.805992
# ...

# %%
df.drop(
    columns=[
        "JobTenure","NetWorth","BaseInterestRate","InterestRate","MonthlyLoanPayment","TotalDebtToIncomeRatio","RiskScore"
    ],
    axis=1,inplace=True
)
df
# Out:
#        AnnualIncome  CreditScore  MonthlyIncome  LoanApproved
# 0             39948          617    3329.000000             0
# 1             39709          628    3309.083333             0
# 2             40724          570    3393.666667             0
# 3             69084          545    5757.000000             0
# 4            103264          594    8605.333333             1
# ...             ...          ...            ...           ...
# 19995         30180          587    2515.000000             0
# 19996         49246          567    4103.833333             0
# 19997         48958          645    4079.833333             0
# 19998         41025          560    3418.750000             0
# 19999         53227          574    4435.583333             0
#
# [20000 rows x 4 columns]

# %%
x=df.drop("LoanApproved",axis=1)
y=df["LoanApproved"]
x
# Out:
#        AnnualIncome  CreditScore  MonthlyIncome
# 0             39948          617    3329.000000
# 1             39709          628    3309.083333
# 2             40724          570    3393.666667
# 3             69084          545    5757.000000
# 4            103264          594    8605.333333
# ...             ...          ...            ...
# 19995         30180          587    2515.000000
# 19996         49246          567    4103.833333
# 19997         48958          645    4079.833333
# 19998         41025          560    3418.750000
# 19999         53227          574    4435.583333
#
# [20000 rows x 3 columns]

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 19995    0
# 19996    0
# 19997    0
# 19998    0
# 19999    0
# Name: LoanApproved, Length: 20000, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test= train_test_split(x, y, test_size=0.2, random_state=42)
x_train
# Out:
#        AnnualIncome  CreditScore  MonthlyIncome
# 5894          15000          620    1250.000000
# 3728          49855          486    4154.583333
# 8958          38932          576    3244.333333
# 7671          58116          516    4843.000000
# 5999          62939          562    5244.916667
# ...             ...          ...            ...
# 11284         37134          569    3094.500000
# 11964         15000          618    1250.000000
# 5390          48088          517    4007.333333
# 860           15265          606    1272.083333
# 15795         45197          631    3766.416667
#
# [16000 rows x 3 columns]

# %%
x_test
# Out:
#        AnnualIncome  CreditScore  MonthlyIncome
# 10650        100761          604    8396.750000
# 2041         189154          509   15762.833333
# 8668          73272          483    6106.000000
# 1114          57115          412    4759.583333
# 13902         61155          551    5096.250000
# ...             ...          ...            ...
# 4073          62891          538    5240.916667
# 7442          37946          615    3162.166667
# 9999          15000          537    1250.000000
# 1870          38443          600    3203.583333
# 15196         59283          481    4940.250000
#
# [4000 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
x_test=sc.fit_transform(x_test)
x_train
# Out:
# array([[-1.09471338,  0.94883443, -1.10472426],
#        [-0.22573729, -1.68545498, -0.21817527],
#        [-0.49806051,  0.08384388, -0.49600556],
#        ...,
#        [-0.26979067, -1.07602982, -0.26311953],
#        [-1.08810662,  0.67361016, -1.0979839 ],
#        [-0.3418667 ,  1.16508207, -0.33665312]], shape=(16000, 3))

# %%
x_test
# Out:
# array([[ 0.983359  ,  0.6383648 ,  1.01188113],
#        [ 3.12475479, -1.20615721,  3.19402775],
#        [ 0.31741453, -1.71097376,  0.33326372],
#        ...,
#        [-1.09427435, -0.66250862, -1.10528965],
#        [-0.52634769,  0.56070071, -0.52655532],
#        [-0.02148092, -1.7498058 , -0.01208092]], shape=(4000, 3))

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([1, 1, 0, ..., 0, 0, 0], shape=(4000,))

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.84075

# %%
#customer purchase prediction
np.random.seed(42)
data ={
    "age" :np.random.randint(18, 25, size=100),
    "monthly_income": np.random.randint(15000,35000,size=100),
    "purchased":np.random.randint(0,2,size=100)
}
df = pd.DataFrame(data)
df.to_csv("customer_purchase.csv", index=False)

# %%
df.head()
# Out:
#    age  monthly_income  purchased
# 0   24           22629          0
# 1   21           16016          1
# 2   22           23529          0
# 3   24           32262          0
# 4   20           24268          0

# %%
df.tail()
# Out:
#     age  monthly_income  purchased
# 95   23           32082          1
# 96   21           19737          0
# 97   23           29555          1
# 98   24           28877          1
# 99   24           15854          1

# %%
df.shape
# Out:
# (100, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             100 non-null    int32
#  1   monthly_income  100 non-null    int32
#  2   purchased       100 non-null    int32
# dtypes: int32(3)
# memory usage: 1.3 KB

# %%
df.describe()
# Out:
#               age  monthly_income   purchased
# count  100.000000      100.000000  100.000000
# mean    21.210000    25310.850000    0.520000
# std      1.913773     5881.898845    0.502117
# min     18.000000    15206.000000    0.000000
# 25%     19.750000    20801.500000    0.000000
# 50%     21.000000    25201.500000    1.000000
# 75%     23.000000    30493.250000    1.000000
# max     24.000000    34965.000000    1.000000

# %%
df.isnull().sum()
# Out:
# age               0
# monthly_income    0
# purchased         0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
x=df.drop("purchased",axis=1)
y=df["purchased"]
x
# Out:
#     age  monthly_income
# 0    24           22629
# 1    21           16016
# 2    22           23529
# 3    24           32262
# 4    20           24268
# ..  ...             ...
# 95   23           32082
# 96   21           19737
# 97   23           29555
# 98   24           28877
# 99   24           15854
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     0
# 1     1
# 2     0
# 3     0
# 4     0
#      ..
# 95    1
# 96    0
# 97    1
# 98    1
# 99    1
# Name: purchased, Length: 100, dtype: int32

# %%
x_train, x_test,y_train,y_test= train_test_split(x, y, test_size=0.2, random_state=42)

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train
# Out:
# array([[ 1.43136352, -0.71171654],
#        [ 0.38082149,  1.31889216],
#        [-0.14444953,  1.53217197],
#        [ 1.43136352, -1.71683618],
#        [ 1.43136352, -1.18192492],
#        [-0.66972054, -1.45579949],
#        [ 0.9060925 ,  0.55478213],
#        [-0.14444953, -0.99192445],
#        [-0.66972054, -0.89966295],
#        [-0.14444953,  1.28636956],
#        [-0.66972054,  1.01266617],
#        [-0.14444953,  0.92468396],
#        [-1.19499156, -0.43441854],
#        [ 0.9060925 ,  0.43393498],
#        [-1.19499156,  0.19121366],
#        [ 0.38082149,  0.28296163],
#        [-1.19499156,  0.12325853],
#        [ 0.38082149,  0.98938683],
#        [ 1.43136352,  0.07413228],
#        [ 0.9060925 , -1.34145686],
#        [-0.66972054,  1.47927995],
#        [-0.66972054,  1.46918082],
#        [ 1.43136352, -0.33565253],
#        [ 0.9060925 ,  1.12118896],
#        [-1.19499156, -0.36629225],
#        [-0.14444953, -0.64975242],
#        [-1.19499156, -1.16121316],
# ...

# %%
x_test
# Out:
# array([[ 0.9060925 , -1.68927755],
#        [ 0.38082149,  0.7339988 ],
#        [-0.14444953,  0.96285523],
#        [-0.14444953, -1.76750297],
#        [-0.66972054,  0.36854743],
#        [ 1.43136352, -0.41456264],
#        [-1.19499156,  0.36529517],
#        [-0.14444953, -0.85618537],
#        [ 1.43136352,  1.35466702],
#        [ 1.43136352, -0.49689618],
#        [-1.19499156, -0.90274404],
#        [-0.14444953,  1.53302783],
#        [ 0.38082149, -0.05167885],
#        [-0.66972054,  0.60031378],
#        [-1.19499156, -0.67559933],
#        [-0.66972054, -0.21634593],
#        [ 0.9060925 , -1.57921421],
#        [-1.72026258, -0.64290555],
#        [-0.66972054,  0.97295435],
#        [-1.72026258, -1.38270921]])

# %%
y_train
# Out:
# 55    1
# 88    0
# 26    1
# 42    0
# 69    1
#      ..
# 60    0
# 71    0
# 14    1
# 92    0
# 51    0
# Name: purchased, Length: 80, dtype: int32

# %%
import numpy as np
print(np.unique(y_train))
# Out:
# [0 1]

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([1, 1, 0, 1, 0, 1, 0, 1, 1, 1, 0, 0, 1, 0, 0, 0, 1, 0, 0, 0],
#       dtype=int32)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.55

# %%
#4th assignment 
#employee attrition prediction
np.random.seed(42)
data = {
    "experience_years": np.random.randint(1,10,size=100),
    "overtime_hours":np.random.randint(1,10,size=100),
    "salary": np.random.randint(10000,50000,size=100),
    "left_company":np.random.randint(0,2,size=100)
}
df=pd.DataFrame(data)
df.to_csv("employee_attrition.csv",index=False)
df.head()
# Out:
#    experience_years  overtime_hours  salary  left_company
# 0                 7               3   47504             0
# 1                 4               5   11802             0
# 2                 8               3   18155             0
# 3                 5               1   18120             1
# 4                 7               5   49384             1

# %%
df.shape
# Out:
# (100, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   experience_years  100 non-null    int32
#  1   overtime_hours    100 non-null    int32
#  2   salary            100 non-null    int32
#  3   left_company      100 non-null    int32
# dtypes: int32(4)
# memory usage: 1.7 KB

# %%
df.describe()
# Out:
#        experience_years  overtime_hours       salary  left_company
# count        100.000000      100.000000    100.00000        100.00
# mean           5.320000        4.820000  28630.96000          0.55
# std            2.639559        2.618427  12456.02222          0.50
# min            1.000000        1.000000  10190.00000          0.00
# 25%            3.000000        3.000000  17091.75000          0.00
# 50%            5.000000        5.000000  28329.50000          1.00
# 75%            8.000000        7.000000  40416.00000          1.00
# max            9.000000        9.000000  49790.00000          1.00

# %%
df.isnull().sum()
# Out:
# experience_years    0
# overtime_hours      0
# salary              0
# left_company        0
# dtype: int64

# %%
df.dtypes
# Out:
# experience_years    int32
# overtime_hours      int32
# salary              int32
# left_company        int32
# dtype: object

# %%
plt.scatter(df["experience_years"],df["salary"])
plt.xlabel("experience_years")
plt.ylabel("salary")
plt.show()

# %%
sns.histplot(df["salary"])
plt.show()

# %%
x=df.drop("left_company", axis=1)
y=df["left_company"]
x
# Out:
#     experience_years  overtime_hours  salary
# 0                  7               3   47504
# 1                  4               5   11802
# 2                  8               3   18155
# 3                  5               1   18120
# 4                  7               5   49384
# ..               ...             ...     ...
# 95                 3               1   26538
# 96                 8               8   20729
# 97                 6               7   44177
# 98                 3               2   10784
# 99                 1               8   37751
#
# [100 rows x 3 columns]

# %%
y
# Out:
# 0     0
# 1     0
# 2     0
# 3     1
# 4     1
#      ..
# 95    1
# 96    0
# 97    0
# 98    0
# 99    1
# Name: left_company, Length: 100, dtype: int32

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test= train_test_split(x, y, test_size=0.2, random_state=42)
x_train
# Out:
#     experience_years  overtime_hours  salary
# 55                 6               1   20677
# 88                 8               3   44663
# 26                 4               9   22874
# 42                 4               8   31295
# 69                 1               6   46212
# ..               ...             ...     ...
# 60                 7               2   49790
# 71                 7               4   43828
# 14                 5               7   41616
# 92                 7               7   21093
# 51                 2               2   16893
#
# [80 rows x 3 columns]

# %%
x_test
# Out:
#     experience_years  overtime_hours  salary
# 83                 5               9   44584
# 53                 6               1   13436
# 70                 9               7   42635
# 45                 3               9   43986
# 44                 8               8   32399
# 39                 9               5   48467
# 22                 9               5   14499
# 80                 3               6   16102
# 10                 8               1   35199
# 0                  7               3   47504
# 18                 2               3   17158
# 30                 3               9   48360
# 73                 8               8   13420
# 33                 9               9   12961
# 90                 1               3   17455
# 4                  7               5   49384
# 76                 8               8   10699
# 77                 3               5   10190
# 12                 3               4   21835
# 31                 7               9   26482

# %%
y_train
# Out:
# 55    0
# 88    1
# 26    1
# 42    0
# 69    1
#      ..
# 60    0
# 71    1
# 14    0
# 92    0
# 51    1
# Name: left_company, Length: 80, dtype: int32

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
x_train
# Out:
# array([[ 3.17675040e-01, -1.41139273e+00, -6.84166114e-01],
#        [ 1.08779635e+00, -6.19031898e-01,  1.36016823e+00],
#        [-4.52446269e-01,  1.75805059e+00, -4.96915111e-01],
#        [-4.52446269e-01,  1.36187018e+00,  2.20809374e-01],
#        [-1.60762823e+00,  5.69509346e-01,  1.49218999e+00],
#        [-1.22256758e+00,  9.65689761e-01,  1.66086078e+00],
#        [-6.73856146e-02, -1.41139273e+00,  3.94082605e-01],
#        [ 1.08779635e+00,  1.36187018e+00, -6.79734137e-01],
#        [-4.52446269e-01,  9.65689761e-01,  1.05350955e+00],
#        [ 1.47285700e+00,  9.65689761e-01,  5.74239249e-04],
#        [ 1.08779635e+00, -2.22851483e-01, -1.98864699e-01],
#        [-4.52446269e-01, -1.41139273e+00, -1.19060465e+00],
#        [ 1.47285700e+00, -6.19031898e-01,  3.74053481e-01],
#        [-8.37506924e-01, -1.41139273e+00, -1.12207947e+00],
#        [ 1.08779635e+00, -2.22851483e-01, -5.40583929e-02],
#        [-8.37506924e-01,  9.65689761e-01,  2.73907860e-01],
# ...

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score
y_pred=model.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.5

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.23      0.38        13
#            1       0.41      1.00      0.58         7
#
#     accuracy                           0.50        20
#    macro avg       0.71      0.62      0.48        20
# weighted avg       0.79      0.50      0.45        20

# %%
#diabetes risk prediction
df=pd.read_csv("diabetes_prediction_dataset.csv")
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
df.shape
# Out:
# (100000, 9)

# %%
df.dtypes
# Out:
# gender                  object
# age                    float64
# hypertension             int64
# heart_disease            int64
# smoking_history         object
# bmi                    float64
# HbA1c_level            float64
# blood_glucose_level      int64
# diabetes                 int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
df.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %%
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(3854)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
sns.histplot(df["age"],bins=5,kde=False)
plt.title("AGE DISTRIBUTION")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96146 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   gender               96146 non-null  object
#  1   age                  96146 non-null  float64
#  2   hypertension         96146 non-null  int64
#  3   heart_disease        96146 non-null  int64
#  4   smoking_history      96146 non-null  object
#  5   bmi                  96146 non-null  float64
#  6   HbA1c_level          96146 non-null  float64
#  7   blood_glucose_level  96146 non-null  int64
#  8   diabetes             96146 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 7.3+ MB

# %%
x=df[["age","bmi","blood_glucose_level"]]
y=df["diabetes"]

# %%
x
# Out:
#         age    bmi  blood_glucose_level
# 0      80.0  25.19                  140
# 1      54.0  27.32                   80
# 2      28.0  27.32                  158
# 3      36.0  23.45                  155
# 4      76.0  20.14                  155
# ...     ...    ...                  ...
# 99994  36.0  24.60                  145
# 99996   2.0  17.37                  100
# 99997  66.0  27.83                  155
# 99998  24.0  35.42                  100
# 99999  57.0  22.43                   90
#
# [96146 rows x 3 columns]

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 99994    0
# 99996    0
# 99997    0
# 99998    0
# 99999    0
# Name: diabetes, Length: 96146, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
x_train
# Out:
#         age    bmi  blood_glucose_level
# 46612  35.0  31.53                  155
# 31612   0.4  15.19                  130
# 96143  60.0  20.90                  100
# 95691  66.0  27.05                  130
# 37658  48.0  24.05                  145
# ...     ...    ...                  ...
# 6284   12.0  20.56                  160
# 56182  62.0  28.34                  160
# 79353  56.0  27.22                  200
# 860    37.0  24.96                  158
# 15910  36.0  27.57                  140
#
# [76916 rows x 3 columns]

# %%
x_test
# Out:
#          age    bmi  blood_glucose_level
# 2547    5.00  15.14                   90
# 34774  19.00  22.74                   85
# 71084  52.00  24.27                  220
# 50584  55.00  27.32                   85
# 80788  22.00  28.78                  200
# ...      ...    ...                  ...
# 19314  10.00  25.37                  200
# 17624  15.00  19.87                  160
# 8673    0.24  27.32                  140
# 37062  50.00  27.32                  145
# 21353   0.16  15.62                  100
#
# [19230 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)
x_train
# Out:
# array([[-0.30198025,  0.62405051,  0.41232842],
#        [-1.84240507, -1.78928416, -0.19857957],
#        [ 0.81104346, -0.94594628, -0.93166916],
#        ...,
#        [ 0.63295967, -0.01251451,  1.51196281],
#        [-0.21293836, -0.34630499,  0.48563738],
#        [-0.2574593 ,  0.0391787 ,  0.04578363]], shape=(76916, 3))

# %%
x_test
# Out:
# array([[-1.63961539, -1.81319937, -1.1892201 ],
#        [-1.01652773, -0.68812629, -1.31160438],
#        [ 0.45217889, -0.46163131,  1.99277125],
#        ...,
#        [-1.85146519, -0.01012172,  0.03462272],
#        [ 0.36316637, -0.01012172,  0.15700701],
#        [-1.85502569, -1.74214212, -0.94445154]], shape=(19230, 3))

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(19230,))

# %%
from sklearn.metrics import accuracy_score
   
accuracy_score(y_test,y_pred)
# Out:
# 0.9369214768590743

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test,y_pred)
# Out:
# array([[17337,   172],
#        [ 1041,   680]])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97     17509
#            1       0.80      0.40      0.53      1721
#
#     accuracy                           0.94     19230
#    macro avg       0.87      0.69      0.75     19230
# weighted avg       0.93      0.94      0.93     19230
