# %%
import pandas as pd 
import numpy as np

# %%
data={
    "name":["kashish","khushi","kanan","vanshika"],
    "age":[20,21,22,23],
    "city":["pathankot","jalandhar","haryana","delhi"],
    "salary":[10000,20000,30000,np.nan]
    
}
data
# Out:
# {'name': ['kashish', 'khushi', 'kanan', 'vanshika'],
#  'age': [20, 21, 22, 23],
#  'city': ['pathankot', 'jalandhar', 'haryana', 'delhi'],
#  'salary': [10000, 20000, 30000, nan]}

# %%
df=pd.DataFrame(data)
df
# Out:
#        name  age       city   salary
# 0   kashish   20  pathankot  10000.0
# 1    khushi   21  jalandhar  20000.0
# 2     kanan   22    haryana  30000.0
# 3  vanshika   23      delhi      NaN

# %%
df["name"]
# Out:
# 0     kashish
# 1      khushi
# 2       kanan
# 3    vanshika
# Name: name, dtype: object

# %%
df.iloc[0]
# Out:
# name        kashish
# age              20
# city      pathankot
# salary      10000.0
# Name: 0, dtype: object

# %%
df.iloc[0:3,2:4]
# Out:
#         city   salary
# 0  pathankot  10000.0
# 1  jalandhar  20000.0
# 2    haryana  30000.0

# %%
df.head()
# Out:
#        name  age       city   salary
# 0   kashish   20  pathankot  10000.0
# 1    khushi   21  jalandhar  20000.0
# 2     kanan   22    haryana  30000.0
# 3  vanshika   23      delhi      NaN

# %%
df.head(2)
# Out:
#       name  age       city   salary
# 0  kashish   20  pathankot  10000.0
# 1   khushi   21  jalandhar  20000.0

# %%
df.iloc[:4]
# Out:
#        name  age       city   salary
# 0   kashish   20  pathankot  10000.0
# 1    khushi   21  jalandhar  20000.0
# 2     kanan   22    haryana  30000.0
# 3  vanshika   23      delhi      NaN

# %%
df.iloc[:]
# Out:
#        name  age       city   salary
# 0   kashish   20  pathankot  10000.0
# 1    khushi   21  jalandhar  20000.0
# 2     kanan   22    haryana  30000.0
# 3  vanshika   23      delhi      NaN

# %%
df
# Out:
#        name  age       city   salary
# 0   kashish   20  pathankot  10000.0
# 1    khushi   21  jalandhar  20000.0
# 2     kanan   22    haryana  30000.0
# 3  vanshika   23      delhi      NaN

# %%
df.loc[[2,3],["name","age"]]
# Out:
#        name  age
# 2     kanan   22
# 3  vanshika   23

# %%
df[df["age"]>20]
# Out:
#        name  age       city   salary
# 1    khushi   21  jalandhar  20000.0
# 2     kanan   22    haryana  30000.0
# 3  vanshika   23      delhi      NaN

# %%
df.city=="delhi"
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# Name: city, dtype: bool

# %%
df[df.salary.isnull()]
# Out:
#        name  age   city  salary
# 3  vanshika   23  delhi     NaN

# %%
df[df["city"].isin(("delhi","haryana"))]
# Out:
#        name  age     city   salary
# 2     kanan   22  haryana  30000.0
# 3  vanshika   23    delhi      NaN

# %%
df.sort_values("age")
# Out:
#        name  age       city   salary
# 0   kashish   20  pathankot  10000.0
# 1    khushi   21  jalandhar  20000.0
# 2     kanan   22    haryana  30000.0
# 3  vanshika   23      delhi      NaN

# %%
df.sort_values("age",ascending=False)
# Out:
#        name  age       city   salary
# 3  vanshika   23      delhi      NaN
# 2     kanan   22    haryana  30000.0
# 1    khushi   21  jalandhar  20000.0
# 0   kashish   20  pathankot  10000.0

# %%
df.sort_values(["age","city"])
# Out:
#        name  age       city   salary
# 0   kashish   20  pathankot  10000.0
# 1    khushi   21  jalandhar  20000.0
# 2     kanan   22    haryana  30000.0
# 3  vanshika   23      delhi      NaN

# %%
df.sort_values(by=["age","city"],ascending=[False,False])
# Out:
#        name  age       city   salary
# 3  vanshika   23      delhi      NaN
# 2     kanan   22    haryana  30000.0
# 1    khushi   21  jalandhar  20000.0
# 0   kashish   20  pathankot  10000.0

# %%
df.isnull()
# Out:
#     name    age   city  salary
# 0  False  False  False   False
# 1  False  False  False   False
# 2  False  False  False   False
# 3  False  False  False    True

# %%
df.isnull().sum()
# Out:
# name      0
# age       0
# city      0
# salary    1
# dtype: int64

# %%
df.dropna()
# Out:
#       name  age       city   salary
# 0  kashish   20  pathankot  10000.0
# 1   khushi   21  jalandhar  20000.0
# 2    kanan   22    haryana  30000.0

# %%
df["salary"]=df["salary"].fillna(df["salary"].median())
df
# Out:
#        name  age       city   salary
# 0   kashish   20  pathankot  10000.0
# 1    khushi   21  jalandhar  20000.0
# 2     kanan   22    haryana  30000.0
# 3  vanshika   23      delhi  20000.0

# %%
df["city"].unique()
# Out:
# array(['pathankot', 'jalandhar', 'haryana', 'delhi'], dtype=object)

# %%
df["city"].nunique()
# Out:
# 4

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
df[df["salary"].duplicated()]
# Out:
#        name  age   city   salary
# 3  vanshika   23  delhi  20000.0

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["tax"]=df["salary"]*0.05
df
# Out:
#        name  age       city   salary     tax
# 0   kashish   20  pathankot  10000.0   500.0
# 1    khushi   21  jalandhar  20000.0  1000.0
# 2     kanan   22    haryana  30000.0  1500.0
# 3  vanshika   23      delhi  20000.0  1000.0

# %%
df["city"]=df["city"].str.upper()
df
# Out:
#        name  age       city   salary     tax
# 0   kashish   20  PATHANKOT  10000.0   500.0
# 1    khushi   21  JALANDHAR  20000.0  1000.0
# 2     kanan   22    HARYANA  30000.0  1500.0
# 3  vanshika   23      DELHI  20000.0  1000.0

# %%
df["name"]=df["name"].str.upper()
df
# Out:
#        name  age       city   salary     tax
# 0   KASHISH   20  PATHANKOT  10000.0   500.0
# 1    KHUSHI   21  JALANDHAR  20000.0  1000.0
# 2     KANAN   22    HARYANA  30000.0  1500.0
# 3  VANSHIKA   23      DELHI  20000.0  1000.0

# %%
df["experience"]=[1,2,3,4]
df
# Out:
#        name  age       city   salary     tax  experience
# 0   KASHISH   20  PATHANKOT  10000.0   500.0           1
# 1    KHUSHI   21  JALANDHAR  20000.0  1000.0           2
# 2     KANAN   22    HARYANA  30000.0  1500.0           3
# 3  VANSHIKA   23      DELHI  20000.0  1000.0           4

# %%
def salary_category(salary):
    if salary<10000:
        return "low"
    elif salary<20000:
        return "medium"
    else:
        return "high"
df["salary_category"]=df["salary"].apply(salary_category)
df
# Out:
#        name  age       city   salary     tax  experience salary_category
# 0   KASHISH   20  PATHANKOT  10000.0   500.0           1          medium
# 1    KHUSHI   21  JALANDHAR  20000.0  1000.0           2            high
# 2     KANAN   22    HARYANA  30000.0  1500.0           3            high
# 3  VANSHIKA   23      DELHI  20000.0  1000.0           4            high
